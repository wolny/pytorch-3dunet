# %%
import unet3d.config
import train

path = '../resources/3DUnet_lightsheet_nuclei/train_config.yaml'

train.logger
# Out:
# <Logger TrainingSetup (INFO)>

# %%
train.main(path)
# Out:
# 2021-08-21 16:54:20,735 [MainThread] INFO ConfigLoader - Using 'cuda:0' device
# ...
